# %% [markdown]
# <a href="https://colab.research.google.com/github/Azmouc1k/azmo-portfolio/blob/main/Perception_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b2a4e899-1424-4505-8b99-bdd924ada326" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b2a4e899-1424-4505-8b99-bdd924ada326">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9cb4a082-fcbd-4870-98fc-c630d04c59d9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9cb4a082-fcbd-4870-98fc-c630d04c59d9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df1
# Out:
#     setSize corKey corAns cue_ref      sq1_col      sq2_col      sq3_col  \
# 0         6      l   diff     sq2  purple.jpeg  yellow.jpeg  yellow.jpeg
# 1         6      l   diff     sq2   white.jpeg     red.jpeg  purple.jpeg
# 2         2      a   same     sq1    blue.jpeg    blue.jpeg     red.jpeg
# 3         4      a   same     sq1   black.jpeg  yellow.jpeg  purple.jpeg
# 4         8      l   diff     sq2  purple.jpeg    blue.jpeg    blue.jpeg
# ..      ...    ...    ...     ...          ...          ...          ...
# 65        4      l   diff     sq3   black.jpeg   green.jpeg    blue.jpeg
# 66        4      a   same     sq2     red.jpeg  yellow.jpeg  purple.jpeg
# 67        2      a   same     sq2  purple.jpeg   black.jpeg  purple.jpeg
# 68        2      a   same     sq1   black.jpeg  yellow.jpeg   black.jpeg
# 69        2      l   diff     sq2     red.jpeg     red.jpeg   green.jpeg
#
#         sq4_col      sq5_col      sq6_col  ... text_8.started  \
# ...

# %%
df1 = pd.read_csv('Mehmed Saadakeev.csv')
df2 = pd.read_csv('Kimamit Askar_new20212003_2022-12-03_17h03.54.880.csv')
df3 = pd.read_csv('Eleonora Kyrbieva _new20212003_2022-12-02_12h49.51.737.csv')
df4 = pd.read_csv('Aziza Abdyrazakova_new20212003_2022-12-03_17h08.14.583.csv')
df5 = pd.read_csv('Les Dias_new20212003_2022-12-03_17h12.34.264.csv')
df6 = pd.read_csv('Tairali Assylbekov_new20212003_2022-12-03_18h41.07.888.csv')
df7 = pd.read_csv('Turtemit Adilet_new20212003_2022-12-03_18h45.29.080.csv')
df8 = pd.read_csv('Kim Artem_new20212003_2022-12-03_18h58.31.751.csv')
df9 = pd.read_csv('Arlan Kalin_new20212003_2022-12-03_19h12.34.904.csv')
df10 = pd.read_csv('10th_new20212003_2022-12-03_19h02.54.155.csv')
df11 = pd.read_csv('11th_new20212003_2022-12-03_19h18.10.012.csv')
df12 = pd.read_csv('12th_new20212003_2022-12-03_19h23.09.996.csv')
df13 = pd.read_csv('13th_new20212003_2022-12-03_19h31.44.934.csv')
df14 = pd.read_csv('14th_new20212003_2022-12-03_19h36.01.270.csv')
df15 = pd.read_csv('15th_new20212003_2022-12-03_19h40.03.772.csv')

# %%
df1
# Out:
#     setSize corKey corAns cue_ref      sq1_col      sq2_col      sq3_col  \
# 0       NaN    NaN    NaN     NaN          NaN          NaN          NaN
# 1       NaN    NaN    NaN     NaN          NaN          NaN          NaN
# 2       NaN    NaN    NaN     NaN          NaN          NaN          NaN
# 3       NaN    NaN    NaN     NaN          NaN          NaN          NaN
# 4       NaN    NaN    NaN     NaN          NaN          NaN          NaN
# ..      ...    ...    ...     ...          ...          ...          ...
# 82      4.0      a   same     sq2     red.jpeg  yellow.jpeg  purple.jpeg
# 83      2.0      a   same     sq2  purple.jpeg   black.jpeg  purple.jpeg
# 84      2.0      a   same     sq1   black.jpeg  yellow.jpeg   black.jpeg
# 85      2.0      l   diff     sq2     red.jpeg     red.jpeg   green.jpeg
# 86      NaN    NaN    NaN     NaN          NaN          NaN          NaN
#
#         sq4_col     sq5_col      sq6_col  ... key_resp_7.rt       participant  \
# ...

# %%
import numpy as np
df1['accuracy'] = np.where(df1['corKey'] == df1['key_resp.keys'], 0, 1)
df2['accuracy'] = np.where(df2['corKey'] == df2['key_resp.keys'], 0, 1)
df3['accuracy'] = np.where(df3['corKey'] == df3['key_resp.keys'], 0, 1)
df4['accuracy'] = np.where(df4['corKey'] == df4['key_resp.keys'], 0, 1)
df5['accuracy'] = np.where(df5['corKey'] == df5['key_resp.keys'], 0, 1)
df6['accuracy'] = np.where(df6['corKey'] == df6['key_resp.keys'], 0, 1)
df7['accuracy'] = np.where(df7['corKey'] == df7['key_resp.keys'], 0, 1)
df8['accuracy'] = np.where(df8['corKey'] == df8['key_resp.keys'], 0, 1)
df9['accuracy'] = np.where(df9['corKey'] == df9['key_resp.keys'], 0, 1)
df10['accuracy'] = np.where(df10['corKey'] == df10['key_resp.keys'], 0, 1)
df11['accuracy'] = np.where(df11['corKey'] == df11['key_resp.keys'], 0, 1)
df12['accuracy'] = np.where(df12['corKey'] == df12['key_resp.keys'], 0, 1)
df13['accuracy'] = np.where(df13['corKey'] == df13['key_resp.keys'], 0, 1)
df14['accuracy'] = np.where(df14['corKey'] == df14['key_resp.keys'], 0, 1)
df15['accuracy'] = np.where(df15['corKey'] == df15['key_resp.keys'], 0, 1)

# %%
df1['percent'] = ''
df2['percent'] = ''
df3['percent'] = ''
df4['percent'] = ''
df5['percent'] = ''
df6['percent'] = ''
df7['percent'] = ''
df8['percent'] = ''
df9['percent'] = ''
df10['percent'] = ''
df11['percent'] = ''
df12['percent'] = ''
df13['percent'] = ''
df14['percent'] = ''
df15['percent'] = ''

# %%
df1
# Out:
#     setSize corKey corAns cue_ref      sq1_col      sq2_col      sq3_col  \
# 0       NaN    NaN    NaN     NaN          NaN          NaN          NaN
# 1       NaN    NaN    NaN     NaN          NaN          NaN          NaN
# 2       NaN    NaN    NaN     NaN          NaN          NaN          NaN
# 3       NaN    NaN    NaN     NaN          NaN          NaN          NaN
# 4       NaN    NaN    NaN     NaN          NaN          NaN          NaN
# ..      ...    ...    ...     ...          ...          ...          ...
# 82      4.0      a   same     sq2     red.jpeg  yellow.jpeg  purple.jpeg
# 83      2.0      a   same     sq2  purple.jpeg   black.jpeg  purple.jpeg
# 84      2.0      a   same     sq1   black.jpeg  yellow.jpeg   black.jpeg
# 85      2.0      l   diff     sq2     red.jpeg     red.jpeg   green.jpeg
# 86      NaN    NaN    NaN     NaN          NaN          NaN          NaN
#
#         sq4_col     sq5_col      sq6_col  ... key_resp_7.rt       participant  \
# ...

# %%
ls = []
for idx, row in df1.iterrows():
    ls.append(df1.loc[idx,'accuracy'])
    df1.loc[idx,'percent'] = (ls.count(1) / len(ls)) * 100

# %%
ls2 = []
for idx, row in df2.iterrows():
    ls2.append(df2.loc[idx,'accuracy'])
    df2.loc[idx,'percent'] = (ls2.count(1) / len(ls2)) * 100

ls3 = []
for idx, row in df3.iterrows():
    ls3.append(df3.loc[idx,'accuracy'])
    df3.loc[idx,'percent'] = (ls3.count(1) / len(ls3)) * 100

ls4 = []
for idx, row in df4.iterrows():
    ls4.append(df4.loc[idx,'accuracy'])
    df4.loc[idx,'percent'] = (ls4.count(1) / len(ls4)) * 100

ls5 = []
for idx, row in df5.iterrows():
    ls5.append(df5.loc[idx,'accuracy'])
    df5.loc[idx,'percent'] = (ls5.count(1) / len(ls5)) * 100

ls6 = []
for idx, row in df6.iterrows():
    ls6.append(df6.loc[idx,'accuracy'])
    df6.loc[idx,'percent'] = (ls6.count(1) / len(ls6)) * 100

ls7 = []
for idx, row in df7.iterrows():
    ls7.append(df7.loc[idx,'accuracy'])
    df7.loc[idx,'percent'] = (ls7.count(1) / len(ls7)) * 100

ls8 = []
for idx, row in df8.iterrows():
    ls8.append(df8.loc[idx,'accuracy'])
    df8.loc[idx,'percent'] = (ls8.count(1) / len(ls8)) * 100


ls9 = []
for idx, row in df9.iterrows():
    ls9.append(df9.loc[idx,'accuracy'])
    df9.loc[idx,'percent'] = (ls9.count(1) / len(ls9)) * 100

ls10 = []
for idx, row in df10.iterrows():
    ls10.append(df10.loc[idx,'accuracy'])
    df10.loc[idx,'percent'] = (ls10.count(1) / len(ls10)) * 100

ls11 = []
for idx, row in df11.iterrows():
    ls11.append(df11.loc[idx,'accuracy'])
    df11.loc[idx,'percent'] = (ls11.count(1) / len(ls11)) * 100


ls12 = []
for idx, row in df12.iterrows():
    ls12.append(df12.loc[idx,'accuracy'])
    df12.loc[idx,'percent'] = (ls12.count(1) / len(ls12)) * 100


ls13 = []
for idx, row in df13.iterrows():
    ls13.append(df13.loc[idx,'accuracy'])
    df13.loc[idx,'percent'] = (ls13.count(1) / len(ls13)) * 100

ls14 = []
for idx, row in df14.iterrows():
    ls14.append(df14.loc[idx,'accuracy'])
    df14.loc[idx,'percent'] = (ls14.count(1) / len(ls14)) * 100

ls15 = []
for idx, row in df15.iterrows():
    ls15.append(df15.loc[idx,'accuracy'])
    df15.loc[idx,'percent'] = (ls15.count(1) / len(ls15)) * 100

# %%
df1
# Out:
#     setSize corKey corAns cue_ref      sq1_col      sq2_col      sq3_col  \
# 0         6      l   diff     sq2  purple.jpeg  yellow.jpeg  yellow.jpeg
# 1         6      l   diff     sq2   white.jpeg     red.jpeg  purple.jpeg
# 2         2      a   same     sq1    blue.jpeg    blue.jpeg     red.jpeg
# 3         4      a   same     sq1   black.jpeg  yellow.jpeg  purple.jpeg
# 4         8      l   diff     sq2  purple.jpeg    blue.jpeg    blue.jpeg
# ..      ...    ...    ...     ...          ...          ...          ...
# 65        4      l   diff     sq3   black.jpeg   green.jpeg    blue.jpeg
# 66        4      a   same     sq2     red.jpeg  yellow.jpeg  purple.jpeg
# 67        2      a   same     sq2  purple.jpeg   black.jpeg  purple.jpeg
# 68        2      a   same     sq1   black.jpeg  yellow.jpeg   black.jpeg
# 69        2      l   diff     sq2     red.jpeg     red.jpeg   green.jpeg
#
#         sq4_col      sq5_col      sq6_col  ... key_resp_7.keys  key_resp_7.rt  \
# ...

# %%
import matplotlib.pyplot as plt
ax = df1.reset_index().plot(x='index', y='percent', label = '1')
plt.ylim(0, 100)
df2.reset_index().plot(x='index', y='percent', ax = ax, label = '2')
plt.ylim(0, 100)
df3.reset_index().plot(x='index', y='percent', ax = ax, label = '3')
plt.ylim(0, 100)
df4.reset_index().plot(x='index', y='percent', ax = ax, label = '4')
plt.ylim(0, 100)
df5.reset_index().plot(x='index', y='percent', ax = ax, label = '5')
plt.ylim(0, 100)
df6.reset_index().plot(x='index', y='percent', ax = ax, label = '6')
plt.ylim(0, 100)
df7.reset_index().plot(x='index', y='percent', ax = ax, label = '7')
plt.ylim(0, 100)
df8.reset_index().plot(x='index', y='percent', ax = ax, label = '8')
plt.ylim(0, 100)
df9.reset_index().plot(x='index', y='percent', ax = ax, label = '9')
plt.ylim(0, 100)
df10.reset_index().plot(x='index', y='percent', ax = ax, label = '10')
plt.ylim(0, 100)
df11.reset_index().plot(x='index', y='percent', ax = ax, label = '11')
plt.ylim(0, 100)
df12.reset_index().plot(x='index', y='percent', ax = ax, label = '12')
plt.ylim(0, 100)
df13.reset_index().plot(x='index', y='percent', ax = ax, label = '13')
plt.ylim(0, 100)
df14.reset_index().plot(x='index', y='percent', ax = ax, label = '14')
plt.ylim(0, 100)
df15.reset_index().plot(x='index', y='percent', ax = ax, label = '15')
plt.ylim(0, 100)
ax.legend(bbox_to_anchor=(1.1, 1.05))
plt.figsize=(500, 200)
plt.xlabel("Index")
plt.ylabel("Accuracy %")
# Out:
# Text(0, 0.5, 'Accuracy %')

# %%
df_new = pd.DataFrame()

# %%
df_new
# Out:
#           df1        df2        df3        df4        df5        df6  \
# 0         0.0      100.0        0.0        0.0      100.0      100.0
# 1         0.0       50.0       50.0       50.0      100.0      100.0
# 2         0.0  33.333333  66.666667  66.666667  66.666667  66.666667
# 3         0.0       25.0       50.0       50.0       50.0       50.0
# 4         0.0       40.0       40.0       60.0       40.0       40.0
# ..        ...        ...        ...        ...        ...        ...
# 65  42.424242  59.090909  57.575758  54.545455  48.484848  48.484848
# 66  41.791045  59.701493  56.716418  53.731343  47.761194  47.761194
# 67  42.647059  58.823529  57.352941  54.411765  48.529412  48.529412
# 68  43.478261  57.971014  56.521739  53.623188  49.275362  49.275362
# 69  42.857143  57.142857  57.142857  54.285714  48.571429  48.571429
#
#           df7        df8        df9       df10       df11       df12  \
# ...

# %%
df_new['avg'] = ''

# %%
df_new['avg'] = (df_new['df1'] +df_new['df2']+df_new['df3']+df_new['df4']+df_new['df5']+df_new['df6']+df_new['df7']+df_new['df8']+df_new['df9']+df_new['df10']+df_new['df11']+df_new['df12']+df_new['df13']+df_new['df14']+df_new['df15']) / 15

# %%
df_new['df1'] = ''
df_new['df1'] = df1['percent']

# %%
df_new['df2'] = ''
df_new['df2'] = df2['percent']

# %%
df_new['df3'] = ''
df_new['df3'] = df3['percent']
df_new['df4'] = ''
df_new['df4'] = df4['percent']
df_new['df5'] = ''
df_new['df5'] = df5['percent']
df_new['df6'] = ''
df_new['df6'] = df6['percent']
df_new['df7'] = ''
df_new['df7'] = df7['percent']
df_new['df8'] = ''
df_new['df8'] = df8['percent']
df_new['df9'] = ''
df_new['df9'] = df9['percent']
df_new['df10'] = ''
df_new['df10'] = df10['percent']
df_new['df11'] = ''
df_new['df11'] = df11['percent']
df_new['df12'] = ''
df_new['df12'] = df12['percent']
df_new['df13'] = ''
df_new['df13'] = df13['percent']
df_new['df14'] = ''
df_new['df14'] = df14['percent']
df_new['df15'] = ''
df_new['df15'] = df15['percent']

# %%
df_new.head
# Out:
# 0         60.0
# 1         60.0
# 2    48.888889
# 3    43.333333
# 4         44.0
# Name: percent, dtype: object

# %%
df_new['avg'] = (df1['percent'] + df2['percent'] + df3['percent'] + df4['percent'] + df5['percent'] + df6['percent']+df7['percent']+df8['percent']+df9['percent']+df10['percent']+df11['percent']+df12['percent']+df13['percent']+df14['percent']+df15['percent']) / 15

# %%
df_new.head()
# Out:
#    df1        df2        df3        df4        df5        df6        df7  \
# 0  0.0      100.0        0.0        0.0      100.0      100.0      100.0
# 1  0.0       50.0       50.0       50.0      100.0      100.0       50.0
# 2  0.0  33.333333  66.666667  66.666667  66.666667  66.666667  66.666667
# 3  0.0       25.0       50.0       50.0       50.0       50.0       50.0
# 4  0.0       40.0       40.0       60.0       40.0       40.0       60.0
#
#          df8        df9       df10       df11       df12       df13  \
# 0        0.0        0.0      100.0      100.0        0.0      100.0
# 1       50.0        0.0       50.0      100.0       50.0      100.0
# 2  33.333333  33.333333  33.333333  66.666667  33.333333  66.666667
# 3       25.0       25.0       50.0       75.0       50.0       75.0
# 4       40.0       20.0       40.0       60.0       60.0       60.0
#
#         df14       df15        avg
# 0      100.0      100.0       60.0
# 1       50.0      100.0       60.0
# ...

# %%
ax = df1.reset_index().plot(x='index', y='percent', label = '1', alpha = 0.2)
plt.ylim(0, 100)
df2.reset_index().plot(x='index', y='percent', ax = ax, label = '2',alpha = 0.2)
plt.ylim(0, 100)
df3.reset_index().plot(x='index', y='percent', ax = ax, label = '3',alpha = 0.2)
plt.ylim(0, 100)
df4.reset_index().plot(x='index', y='percent', ax = ax, label = '4',alpha = 0.2)
plt.ylim(0, 100)
df5.reset_index().plot(x='index', y='percent', ax = ax, label = '5',alpha = 0.2)
plt.ylim(0, 100)
df6.reset_index().plot(x='index', y='percent', ax = ax, label = '6',alpha = 0.2)
plt.ylim(0, 100)
df7.reset_index().plot(x='index', y='percent', ax = ax, label = '7',alpha = 0.2)
plt.ylim(0, 100)
df8.reset_index().plot(x='index', y='percent', ax = ax, label = '8',alpha = 0.2)
plt.ylim(0, 100)
df9.reset_index().plot(x='index', y='percent', ax = ax, label = '9',alpha = 0.2)
plt.ylim(0, 100)
df10.reset_index().plot(x='index', y='percent', ax = ax, label = '10',alpha = 0.2)
plt.ylim(0, 100)
df11.reset_index().plot(x='index', y='percent', ax = ax, label = '11',alpha = 0.2)
plt.ylim(0, 100)
df12.reset_index().plot(x='index', y='percent', ax = ax, label = '12',alpha = 0.2)
plt.ylim(0, 100)
df13.reset_index().plot(x='index', y='percent', ax = ax, label = '13',alpha = 0.2)
plt.ylim(0, 100)
df14.reset_index().plot(x='index', y='percent', ax = ax, label = '14',alpha = 0.2)
plt.ylim(0, 100)
df15.reset_index().plot(x='index', y='percent', ax = ax, label = '15',alpha = 0.2)
plt.ylim(0, 100)
ax.legend(bbox_to_anchor=(1.1, 1.05))
plt.xlabel("Index")
plt.ylabel("Accuracy %")
plt.savefig('transparent_accuracy.png', dpi=500, bbox_inches='tight')
plt.show()

# %%
ax = df1.reset_index().plot(x='index', y='percent', label = '1', alpha = 0.2)
plt.ylim(0, 100)
df2.reset_index().plot(x='index', y='percent', ax = ax, label = '2',alpha = 0.2)
plt.ylim(0, 100)
df3.reset_index().plot(x='index', y='percent', ax = ax, label = '3',alpha = 0.2)
plt.ylim(0, 100)
df4.reset_index().plot(x='index', y='percent', ax = ax, label = '4',alpha = 0.2)
plt.ylim(0, 100)
df5.reset_index().plot(x='index', y='percent', ax = ax, label = '5',alpha = 0.2)
plt.ylim(0, 100)
df6.reset_index().plot(x='index', y='percent', ax = ax, label = '6',alpha = 0.2)
plt.ylim(0, 100)
df7.reset_index().plot(x='index', y='percent', ax = ax, label = '7',alpha = 0.2)
plt.ylim(0, 100)
df8.reset_index().plot(x='index', y='percent', ax = ax, label = '8',alpha = 0.2)
plt.ylim(0, 100)
df9.reset_index().plot(x='index', y='percent', ax = ax, label = '9',alpha = 0.2)
plt.ylim(0, 100)
df10.reset_index().plot(x='index', y='percent', ax = ax, label = '10',alpha = 0.2)
plt.ylim(0, 100)
df11.reset_index().plot(x='index', y='percent', ax = ax, label = '11',alpha = 0.2)
plt.ylim(0, 100)
df12.reset_index().plot(x='index', y='percent', ax = ax, label = '12',alpha = 0.2)
plt.ylim(0, 100)
df13.reset_index().plot(x='index', y='percent', ax = ax, label = '13',alpha = 0.2)
plt.ylim(0, 100)
df14.reset_index().plot(x='index', y='percent', ax = ax, label = '14',alpha = 0.2)
plt.ylim(0, 100)
df15.reset_index().plot(x='index', y='percent', ax = ax, label = '15',alpha = 0.2)
plt.ylim(0, 100)
df_new.reset_index().plot(x = 'index', y = 'avg', ax = ax, label = "average", color = 'black')
ax.legend(bbox_to_anchor=(1.1, 1.05))
plt.xlabel("Index")
plt.ylabel("Accuracy %")
plt.savefig('avg_accuracy.png', dpi=500, bbox_inches='tight')

# %%
df1.reset_index().plot(x='index', y='percent')
plt.ylim(0, 100)
plt.xlabel("Index")
plt.ylabel("Accuracy %")
plt.savefig('df1_accuracy.png', dpi=500, bbox_inches='tight')
df2.reset_index().plot(x='index', y='percent')
plt.xlabel("Index")
plt.ylabel("Accuracy %")
plt.ylim(0, 100)
plt.savefig('df2_accuracy.png', dpi=500, bbox_inches='tight')
df3.reset_index().plot(x='index', y='percent')
plt.ylim(0, 100)
plt.xlabel("Index")
plt.ylabel("Accuracy %")
plt.savefig('df3_accuracy.png', dpi=500, bbox_inches='tight')
df4.reset_index().plot(x='index', y='percent')
plt.ylim(0, 100)
plt.xlabel("Index")
plt.ylabel("Accuracy %")
plt.savefig('df4_accuracy.png', dpi=500, bbox_inches='tight')
df5.reset_index().plot(x='index', y='percent')
plt.ylim(0, 100)
plt.xlabel("Index")
plt.ylabel("Accuracy %")
plt.savefig('df5_accuracy.png', dpi=500, bbox_inches='tight')
df6.reset_index().plot(x='index', y='percent')
plt.ylim(0, 100)
plt.xlabel("Index")
plt.ylabel("Accuracy %")
plt.savefig('df6_accuracy.png', dpi=500, bbox_inches='tight')
df7.reset_index().plot(x='index', y='percent')
plt.ylim(0, 100)
plt.xlabel("Index")
plt.ylabel("Accuracy %")
plt.savefig('df7_accuracy.png', dpi=500, bbox_inches='tight')
df8.reset_index().plot(x='index', y='percent')
plt.ylim(0, 100)
plt.xlabel("Index")
plt.ylabel("Accuracy %")
plt.savefig('df8_accuracy.png', dpi=500, bbox_inches='tight')
df9.reset_index().plot(x='index', y='percent')
plt.ylim(0, 100)
plt.xlabel("Index")
plt.ylabel("Accuracy %")
plt.savefig('df9_accuracy.png', dpi=500, bbox_inches='tight')
df10.reset_index().plot(x='index', y='percent')
plt.ylim(0, 100)
plt.xlabel("Index")
plt.ylabel("Accuracy %")
plt.savefig('df10_accuracy.png', dpi=500, bbox_inches='tight')
df11.reset_index().plot(x='index', y='percent')
plt.ylim(0, 100)
plt.xlabel("Index")
plt.ylabel("Accuracy %")
plt.savefig('df11_accuracy.png', dpi=500, bbox_inches='tight')
df12.reset_index().plot(x='index', y='percent')
plt.ylim(0, 100)
plt.xlabel("Index")
plt.ylabel("Accuracy %")
plt.savefig('df12_accuracy.png', dpi=500, bbox_inches='tight')
df13.reset_index().plot(x='index', y='percent')
plt.ylim(0, 100)
plt.xlabel("Index")
plt.ylabel("Accuracy %")
plt.savefig('df13_accuracy.png', dpi=500, bbox_inches='tight')
df14.reset_index().plot(x='index', y='percent')
plt.ylim(0, 100)
plt.xlabel("Index")
plt.ylabel("Accuracy %")
plt.savefig('df14_accuracy.png', dpi=500, bbox_inches='tight')
df15.reset_index().plot(x='index', y='percent')
plt.ylim(0, 100)
plt.xlabel("Index")
plt.ylabel("Accuracy %")
plt.savefig('df15_accuracy.png', dpi=500, bbox_inches='tight')

# %%
# reaction time
ax = df1.reset_index().plot(x='index', y='key_resp.rt', label = '1')

df2.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '2')
df3.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '3')
df4.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '4')
df5.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '5')
df6.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '6')
df7.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '7')
df8.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '8')
df9.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '9')
df10.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '10')
df11.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '11')
df12.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '12')
df13.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '13')
df14.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '14')
df15.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '15')
ax.legend(bbox_to_anchor=(1.1, 1.05))
plt.xlabel("Index")
plt.ylabel("RT")
plt.savefig('RT.png', dpi=500, bbox_inches='tight')

# %%
# reaction time
from matplotlib.pyplot import figure



ax = df1.reset_index().plot(x='index', y='key_resp.rt', label = '1', alpha = 0.2)

df2.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '2',alpha = 0.2)
df3.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '3',alpha = 0.2)
df4.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '4',alpha = 0.2)
df5.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '5',alpha = 0.2)
df6.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '6',alpha = 0.2)
df7.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '7',alpha = 0.2)
df8.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '8',alpha = 0.2)
df9.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '9',alpha = 0.2)
df10.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '10',alpha = 0.2)
df11.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '11',alpha = 0.2)
df12.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '12',alpha = 0.2)
df13.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '13',alpha = 0.2)
df14.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '14',alpha = 0.2)
df15.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '15',alpha = 0.2)
ax.legend(bbox_to_anchor=(1.1, 1.05))
plt.xlabel("Index")
plt.ylabel("RT")
figure(figsize=(50, 40), dpi=500)
plt.savefig('RT_trasnparent.png', dpi=500, bbox_inches='tight')

# %%
# reaction time
from matplotlib.pyplot import figure



ax = df1.reset_index().plot(x='index', y='key_resp.rt', label = '1', alpha = 0.2)

df2.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '2',alpha = 0.2)
df3.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '3',alpha = 0.2)
df4.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '4',alpha = 0.2)
df5.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '5',alpha = 0.2)
df6.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '6',alpha = 0.2)
df7.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '7',alpha = 0.2)
df8.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '8',alpha = 0.2)
df9.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '9',alpha = 0.2)
df10.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '10',alpha = 0.2)
df11.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '11',alpha = 0.2)
df12.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '12',alpha = 0.2)
df13.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '13',alpha = 0.2)
df14.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '14',alpha = 0.2)
df15.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '15',alpha = 0.2)
ax.legend(bbox_to_anchor=(1.1, 1.05))
plt.xlabel("Index")
plt.ylabel("RT")
figure(figsize=(50, 40), dpi=500)
plt.savefig('RT_trasnparent.png', dpi=500, bbox_inches='tight')

# %%
df_rt = pd.DataFrame()

# %%
df_rt['df1'] = ''
df_rt['df1'] = df1['key_resp.rt']
df_rt['df2'] = ''
df_rt['df2'] = df2['key_resp.rt']
df_rt['df3'] = ''
df_rt['df3'] = df3['key_resp.rt']
df_rt['df4'] = ''
df_rt['df4'] = df4['key_resp.rt']
df_rt['df5'] = ''
df_rt['df5'] = df5['key_resp.rt']
df_rt['df6'] = ''
df_rt['df6'] = df6['key_resp.rt']
df_rt['df7'] = ''
df_rt['df7'] = df7['key_resp.rt']
df_rt['df8'] = ''
df_rt['df8'] = df8['key_resp.rt']
df_rt['df9'] = ''
df_rt['df9'] = df9['key_resp.rt']
df_rt['df10'] = ''
df_rt['df10'] = df10['key_resp.rt']
df_rt['df11'] = ''
df_rt['df11'] = df11['key_resp.rt']
df_rt['df12'] = ''
df_rt['df12'] = df12['key_resp.rt']
df_rt['df13'] = ''
df_rt['df13'] = df13['key_resp.rt']
df_rt['df14'] = ''
df_rt['df14'] = df14['key_resp.rt']
df_rt['df15'] = ''
df_rt['df15'] = df15['key_resp.rt']

# %%
df_rt
# Out:
#          df1       df2       df3       df4       df5       df6       df7  \
# 0   1.244204  0.582898  1.339079  0.873465  1.835008  1.046904  0.781486
# 1   1.614781  0.545337  1.070138  1.852940  0.550051  0.987707  2.671659
# 2   0.665483  0.956410  1.329264  0.700560  0.291587  1.219542  0.689240
# 3   1.873685  1.187441  1.465610  1.072444  0.039693  0.805271  0.586455
# 4   3.062908  1.629275  0.779553  0.668523  0.318441  0.780041  2.732031
# ..       ...       ...       ...       ...       ...       ...       ...
# 65  1.148324  0.573606  0.706831  1.250495  0.896036  1.245707  0.490226
# 66  0.647892  0.711460  0.821483  0.736013  0.845789  1.649585  1.472746
# 67  0.840994  1.226722  0.925369  0.877571  1.067331  0.504856  0.897206
# 68  0.939760  0.620431  1.507728  0.645570  0.615987  0.746134  0.723842
# 69  0.497501  1.308607  0.716458  1.633647  2.675326  1.244203  1.190422
#
#          df8       df9      df10      df11      df12      df13      df14  \
# ...

# %%
df_rt['avg_rt'] = (df_rt['df1'] + df_rt['df2'] + df_rt['df3'] + df_rt['df4'] + df_rt['df5'] + df_rt['df6'] + df_rt['df7'] + df_rt['df8'] + df_rt['df9'] + df_rt['df10'] + df_rt['df11'] + df_rt['df12'] + df_rt['df13'] + df_rt['df14'] + df_rt['df15']) / 15

# %%
df_rt
# Out:
#          df1       df2       df3       df4       df5       df6       df7  \
# 0   1.244204  0.582898  1.339079  0.873465  1.835008  1.046904  0.781486
# 1   1.614781  0.545337  1.070138  1.852940  0.550051  0.987707  2.671659
# 2   0.665483  0.956410  1.329264  0.700560  0.291587  1.219542  0.689240
# 3   1.873685  1.187441  1.465610  1.072444  0.039693  0.805271  0.586455
# 4   3.062908  1.629275  0.779553  0.668523  0.318441  0.780041  2.732031
# ..       ...       ...       ...       ...       ...       ...       ...
# 65  1.148324  0.573606  0.706831  1.250495  0.896036  1.245707  0.490226
# 66  0.647892  0.711460  0.821483  0.736013  0.845789  1.649585  1.472746
# 67  0.840994  1.226722  0.925369  0.877571  1.067331  0.504856  0.897206
# 68  0.939760  0.620431  1.507728  0.645570  0.615987  0.746134  0.723842
# 69  0.497501  1.308607  0.716458  1.633647  2.675326  1.244203  1.190422
#
#          df8       df9      df10      df11      df12      df13      df14  \
# ...

# %%
# reaction time
from matplotlib.pyplot import figure



ax = df1.reset_index().plot(x='index', y='key_resp.rt', label = '1', alpha = 0.2)

df2.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '2',alpha = 0.2)
df3.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '3',alpha = 0.2)
df4.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '4',alpha = 0.2)
df5.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '5',alpha = 0.2)
df6.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '6',alpha = 0.2)
df7.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '7',alpha = 0.2)
df8.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '8',alpha = 0.2)
df9.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '9',alpha = 0.2)
df10.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '10',alpha = 0.2)
df11.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '11',alpha = 0.2)
df12.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '12',alpha = 0.2)
df13.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '13',alpha = 0.2)
df14.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '14',alpha = 0.2)
df15.reset_index().plot(x='index', y='key_resp.rt', ax = ax, label = '15',alpha = 0.2)
ax.legend(bbox_to_anchor=(1.1, 1.05))
plt.xlabel("Index")
plt.ylabel("RT")
figure(figsize=(50, 40), dpi=500)
df_rt.reset_index().plot(x = 'index', y = 'avg_rt', ax = ax, label = "average", color = 'black')
plt.savefig('RT_avg.png', dpi=500, bbox_inches='tight')
